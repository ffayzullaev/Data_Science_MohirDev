# %% [markdown]
# <a href="https://colab.research.google.com/github/ffayzullaev/Data_Science_MohirDev/blob/main/2_2_3_Foydali_funksiyalar_(davomi).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science va Sun'iy Intellekt Praktikum

# %% [markdown]
# Ma'lumotlar tahlili. Pandas kutubxonasi

# %% [markdown]
# 2.2.3 Foydali funksiyalar (davomi)

# %% [markdown]
# Arifmetik amallar

# %% [markdown]
# Ikki **Series** yoki **DataFrame** obyektlari o'rtasida arifmetik amallar bajarishda indekslar juda muhim rol o'ynaydi.

# %% [markdown]
# Amallar mos tushuvchi indekslar o'rtasida bajariladi. Agar obyektlarning birida mavjud indeks ikkinchisda yo'q bo'lsa natija NaN bo'ladi.

# %%
import pandas as pd

# %%
import numpy as np

# %%
s1=pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s2=pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# E'tibor bering, **s1** da mavjud **d** indeksi **s2da** mavjud bo'lmaganligi sabab s1+**s2** da **d** indeksdagi qiymat **NaN** bo'ldi.

# %% [markdown]
# Yuqoridagi holat **DataFramelarga** ham xos. **Serieslardan** farqli ravishda DataFrameda qator va ustun indekslari hisobga olinadi.

# %%
df1=pd.DataFrame(np.arange(9.).reshape(3,3), columns=list('bcd'), index=['Olma', 'Anor', 'Uzum'])
df2=pd.DataFrame(np.arange(12.).reshape(4,3), columns=list('abc'), index=['Olma', 'Anor', 'Qovun', 'Anjir'])

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df1+df2
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %% [markdown]
# **a** va **d** ustunlar hamda **Qovun** va **Anjir** qatorlar ikkala **DataFrameda** bo'lmagani sababli yuqoridagi natija chiqdi

# %% [markdown]
# Yuqoridagi qo'shish amalini **.add() **metodi yordamida ham bajarish mumkin.

# %%
df1.add(df2)
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %% [markdown]
# Bunda maxsus *fill_value* parametri yordamida mos tushuvchi indekslardagi NaN qiymatlarni boshqa qiymat bilan almashtirish mumkin. Bu usulda yakuniy natijada ikkala df da ham mavjud bo'lmagan indekslarda *NaN* qiymati qoladi.

# %%
df2.add(df1, fill_value=0)
# Out:
#          a     b     c    d
# Anjir  9.0  10.0  11.0  NaN
# Anor   3.0   7.0   9.0  5.0
# Olma   0.0   1.0   3.0  2.0
# Qovun  6.0   7.0   8.0  NaN
# Uzum   NaN   6.0   7.0  8.0

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %% [markdown]
# # Boshqa arifmetik amallar
#
# add, radd - Qo'shish (+)
# sub, rsub - Ayirish (-)
# div, rdiv - Bo'lish (/)
# floordiv, rfloordiv - Bo'lish va butun qismini olis (//)
# mul, rmul - Ko'paytirish (*)
# pow, rpow - Eksponenta (**)

# %% [markdown]
# Yuqoridagi amallarning barchasida fill_value parametri mavjud.

# %% [markdown]
# **r** bilan boshlangan metodlarda **DataFrame** ifodaning o'ng tarafida bo'ladi.

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df1.sub(2) #df-2 degani
# Out:
#         b    c    d
# Olma -2.0 -1.0  0.0
# Anor  1.0  2.0  3.0
# Uzum  4.0  5.0  6.0

# %%
df2.rsub(2) #2-df degani
# Out:
#          a    b    c
# Olma   2.0  1.0  0.0
# Anor  -1.0 -2.0 -3.0
# Qovun -4.0 -5.0 -6.0
# Anjir -7.0 -8.0 -9.0

# %% [markdown]
# **DataFrame** va **Series** o'rtasida arifmetik amallar

# %%
df=pd.DataFrame(np.arange(1,13.).reshape(3,4), index=list('abc'), columns=['Olma', 'Anor', 'Qovun', 'Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0   2.0    3.0    4.0
# b   5.0   6.0    7.0    8.0
# c   9.0  10.0   11.0   12.0

# %%
obj=pd.Series([1,1,2,2], index=df.columns)
obj
# Out:
# Olma     1
# Anor     1
# Qovun    2
# Anjir    2
# dtype: int64

# %%
df-obj
# Out:
#    Olma  Anor  Qovun  Anjir
# a   0.0   1.0    1.0    2.0
# b   4.0   5.0    5.0    6.0
# c   8.0   9.0    9.0   10.0

# %%
obj = pd.Series([2,3,1], index=['Olma', 'Uzum', 'Qovun'])
obj
# Out:
# Olma     2
# Uzum     3
# Qovun    1
# dtype: int64

# %%
df+obj
# Out:
#    Anjir  Anor  Olma  Qovun  Uzum
# a    NaN   NaN   3.0    4.0   NaN
# b    NaN   NaN   7.0    8.0   NaN
# c    NaN   NaN  11.0   12.0   NaN

# %%
df-obj['Olma']
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0   0.0    1.0    2.0
# b   3.0   4.0    5.0    6.0
# c   7.0   8.0    9.0   10.0

# %%
df.add(obj['Qovun'])
# Out:
#    Olma  Anor  Qovun  Anjir
# a   2.0   3.0    4.0    5.0
# b   6.0   7.0    8.0    9.0
# c  10.0  11.0   12.0   13.0

# %% [markdown]
# # pandas Obyekti elementlariga Funksiyalarni qo'llash

# %%
df=pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma', 'Anor', 'Qovun', 'Anir'])
df
# Out:
#        Olma      Anor     Qovun      Anir
# a  1.286703 -1.100579 -1.632056  0.363156
# b  0.297895 -0.285360  1.231523 -0.305035
# c -0.619769 -1.381852 -1.072368 -1.563436

# %% [markdown]
# Biror funksiyani DF barcha elementlariga qo'llash:

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun      Anir
# a  1.286703  1.100579  1.632056  0.363156
# b  0.297895  0.285360  1.231523  0.305035
# c  0.619769  1.381852  1.072368  1.563436

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anir
# a   1.0  -1.0   -2.0   0.0
# b   0.0  -0.0    1.0  -0.0
# c  -1.0  -1.0   -1.0  -2.0

# %%
df.mean()
# Out:
# Olma     0.321610
# Anor    -0.922597
# Qovun   -0.490967
# Anir    -0.501771
# dtype: float64

# %% [markdown]
# Yuqoridagi funksiyalarni** .apply()** metodi yordamida ham qo'llash mumkin.

# %%
df
# Out:
#        Olma      Anor     Qovun      Anir
# a  1.286703 -1.100579 -1.632056  0.363156
# b  0.297895 -0.285360  1.231523 -0.305035
# c -0.619769 -1.381852 -1.072368 -1.563436

# %%
df.apply(np.mean)
# Out:
# Olma     0.321610
# Anor    -0.922597
# Qovun   -0.490967
# Anir    -0.501771
# dtype: float64

# %% [markdown]
# *.apply()* yordamida funksiyani ustun yoki qatorga qo'llashni ko'rsatishimiz mumkin

# %%
df.apply(np.sum, axis='columns')
# Out:
# a   -1.082776
# b    0.939023
# c   -4.637425
# dtype: float64

# %% [markdown]
# Bu metodning afzalligi, o'zingiz istalgan funksiyani yozib uni DF elementlariga qo'llashigniz mumkin:

# %%
#DF qatori max va min qiymati ayirmasini hisoblaydigan funksiya
f = lambda x: x.max() - x.min()

# %%
df.apply(f)
# Out:
# Olma     1.906472
# Anor     1.096491
# Qovun    2.863579
# Anir     1.926592
# dtype: float64

# %% [markdown]
# Funksiya nafaqat yagona qiymat, balki series obyektini ham qaytarishi mumkin

# %%
def foo(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun      Anir
# min -0.619769 -1.381852 -1.632056 -1.563436
# max  1.286703 -0.285360  1.231523  0.363156

# %% [markdown]
# Biror funksiyani DF har bir elementiga alohida qo'llash uchun *.applymap() *metodidan foydalaning.

# %%
f = lambda x:x*x #qiymatini kvadratga oshiruvchi funksiya

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma', 'Anor', 'Qovun', 'Anjir'])

# %%
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(f)
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     4      9     16
# b    25    36     49     64
# c    81   100    121    144

# %% [markdown]
# *Tartiblash va Reytinglash*

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# Series obyektini Indeks bo'yicha tartiblash

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %% [markdown]
# Series obyketini Qiymatlari bo'yucha tartiblash

# %%
obj.sort_values()
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# DataFrameni qatorlari yoki ustunlari bo'yicha tartilash mumkin

# %%
# Keling keyingi mashqlar uchun Githubdan kattaroq DF yuklab olamiz
df=pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv', index_col=0)
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
df.sort_index()
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# ...

# %%
df.sort_index(axis=1) # Ustun nomi bo'yicha tartiblash
# Out:
#           brand   color      condition country        lot  mileage    model  \
# 0        toyota   black   10 days left     usa  159348797   274117  cruiser
# 1          ford  silver    6 days left     usa  166951262   190552       se
# 2         dodge  silver    2 days left     usa  167655728    39590      mpv
# 3          ford    blue  22 hours left     usa  167753855    64146     door
# 4     chevrolet     red  22 hours left     usa  167763266     6654     1500
# ...         ...     ...            ...     ...        ...      ...      ...
# 2494     nissan     red    1 days left     usa  167722715    23609    versa
# 2495     nissan  silver  21 hours left     usa  167762225    34553    versa
# 2496     nissan  silver  21 hours left     usa  167762226    31594    versa
# 2497     nissan   black    2 days left     usa  167762227    32557    versa
# 2498     nissan  silver  21 hours left     usa  167762228    31371    versa
#
# ...

# %%
df.sort_index(axis=1, ascending=False) # teskari tartiblash
# Out:
#       year                  vin   title_status       state  price    model  \
# 0     2008    jtezu11f88k007763  clean vehicle  new jersey   6300  cruiser
# 1     2011    2fmdk3gc4bbb02217  clean vehicle   tennessee   2899       se
# 2     2018    3c4pdcgg5jt346413  clean vehicle     georgia   5350      mpv
# 3     2014    1ftfw1et4efc23745  clean vehicle    virginia  25000     door
# 4     2018    3gcpcrec2jg473991  clean vehicle     florida  27700     1500
# ...    ...                  ...            ...         ...    ...      ...
# 2494  2019    3n1cn7ap9kl880319  clean vehicle  california   7800    versa
# 2495  2018    3n1cn7ap5jl884088  clean vehicle     florida   9200    versa
# 2496  2018    3n1cn7ap9jl884191  clean vehicle     florida   9200    versa
# 2497  2018    3n1cn7ap3jl883263  clean vehicle     florida   9200    versa
# 2498  2018    3n1cn7ap4jl884311  clean vehicle     florida   9200    versa
#
#       mileage        lot country      condition   color      brand
# ...

# %% [markdown]
# DataFrame elementlarini biror ustun(lar) bo'yicha tartiblash ham mumkin

# %%
df.sort_values(by='price', ascending=False )
# Out:
#       price          brand       model  year       title_status  mileage  \
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1215  65500           ford         srw  2019      clean vehicle     6500
# ...     ...            ...         ...   ...                ...      ...
# 141       0          dodge         van  2008  salvage insurance   177948
# 391       0       cadillac       coupe  2000  salvage insurance   105169
# 285       0           ford        door  2000  salvage insurance   124969
# 290       0          mazda        door  2009  salvage insurance   117541
# 354       0           ford      pickup  2009  salvage insurance   180364
#
#          color                  vin        lot      state country  \
# ...

# %%
df.sort_values(by=['price', 'mileage'], ascending=False)
# Out:
#       price          brand       model  year       title_status  mileage  \
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1215  65500           ford         srw  2019      clean vehicle     6500
# ...     ...            ...         ...   ...                ...      ...
# 196       0           ford         mpv  2017      clean vehicle    76858
# 349       0      heartland    sundance  2009      clean vehicle        1
# 309       0      chevrolet        door  2004  salvage insurance        0
# 322       0           ford     chassis  1994  salvage insurance        0
# 545       0            gmc        door  1993  salvage insurance        0
#
#            color                  vin        lot         state country  \
# ...

# %% [markdown]
# *.rank()* metodi yordamida Df qatorlarini reytingini aniqlash mumkin. Reyting aniqlashda aynan qaysi ko'rsatkich (ustun) bo'yicvha reytingni aniqlash ko'rsatiladi

# %%
# Moshinalarni mileage (yurgan kilometri) bo'yicha reytinglaymiz
df['rank'] = df['mileage'].rank()
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition  \
# ...

# %%
df.sort_values('mileage')
# Out:
#       price      brand   model  year       title_status  mileage       color  \
# 545       0        gmc    door  1993  salvage insurance        0  light blue
# 504     100  peterbilt   truck  2012  salvage insurance        0        blue
# 1619    650       ford    door  2017  salvage insurance        0       black
# 309       0  chevrolet    door  2004  salvage insurance        0      maroon
# 1236   4200       ford    door  2013      clean vehicle        0    no_color
# ...     ...        ...     ...   ...                ...      ...         ...
# 531    2000  chevrolet  pickup  2003      clean vehicle   507985         red
# 490     475  peterbilt   truck  2012  salvage insurance   902041        gold
# 516       0  peterbilt   truck  2009  salvage insurance   982486        blue
# 1827   3200       ford    door  2013      clean vehicle   999999      silver
# 528    1025  peterbilt   truck  2010  salvage insurance  1017936      color:
#
# ...

# %%
# .rank() method parametri yordamida reyting o'lchash usulini tanlash mumkin (min, max, average, first, dense)
df['rank'] = df['year'].rank(method='average')
df.sort_values('year')
# Out:
#       price      brand     model  year       title_status  mileage  \
# 32    29800  chevrolet    camaro  1973      clean vehicle    46226
# 405      25       ford      door  1984  salvage insurance    41577
# 545       0        gmc      door  1993  salvage insurance        0
# 362      25       ford    pickup  1994  salvage insurance   206162
# 322       0       ford   chassis  1994  salvage insurance        0
# ...     ...        ...       ...   ...                ...      ...
# 426   55600      lexus        gx  2020      clean vehicle     8186
# 806   28300  chevrolet  colorado  2020      clean vehicle    13886
# 2322  15000     nissan    altima  2020      clean vehicle    14320
# 2344  20100     nissan     rogue  2020      clean vehicle    10875
# 1388  17000       ford    fusion  2020      clean vehicle     1117
#
#            color                  vin        lot         state country  \
# 32           red        1q87t3n166389  167763370  pennsylvania     usa
# ...

# %%
df['rank']=df['price'].rank(method='min')
df.sort_values('price')
# Out:
#       price          brand       model  year       title_status  mileage  \
# 410       0      chevrolet        door  1995  salvage insurance   274706
# 330       0           ford        door  1996  salvage insurance   296860
# 331       0           ford        door  2006  salvage insurance   203158
# 339       0           ford        door  2002  salvage insurance   214800
# 496       0           ford      pickup  1996  salvage insurance   252588
# ...     ...            ...         ...   ...                ...      ...
# 1215  65500           ford         srw  2019      clean vehicle     6500
# 277   67000          dodge  challenger  2019      clean vehicle    10944
# 1336  70000           ford         drw  2019      clean vehicle     9643
# 1340  74000           ford         drw  2019      clean vehicle    10536
# 502   84900  mercedes-benz    sl-class  2017      clean vehicle    25302
#
#          color                  vin        lot           state country  \
# ...

# %%
df['rank'] = df['color'].rank(method='average')
df.sort_values('color')
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 135   24005  chevrolet     1500  2017  clean vehicle    51293   beige
# 168   20105      buick     door  2016  clean vehicle    51393   beige
# 460   15010   infiniti      mpv  2019  clean vehicle    11394   beige
# 149    6700       ford  cutaway  2014  clean vehicle   204155   beige
# 2418   3000     nissan     door  2015  clean vehicle   132655   beige
# ...     ...        ...      ...   ...            ...      ...     ...
# 485   11200       jeep      mpv  2019  clean vehicle     8395  yellow
# 1362  39500       ford    f-150  2019  clean vehicle    25071  yellow
# 1363  33100       ford    f-150  2019  clean vehicle    33538  yellow
# 536   11100       jeep      mpv  2019  clean vehicle    11449  yellow
# 548   11030       jeep      mpv  2019  clean vehicle    10861  yellow
#
#                       vin        lot         state country      condition  \
# ...

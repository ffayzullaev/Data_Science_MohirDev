# %% [markdown]
# <a href="https://colab.research.google.com/github/ffayzullaev/Data_Science_MohirDev/blob/main/_3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ma'lumotlar tahlili

# %% [markdown]
# Pandas kutubxonasi

# %% [markdown]
# Foydali funksiyalar

# %%
import pandas as pd
import numpy as np

# %%
data={'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
      'Aholi soni':[33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
      'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53],
      'Zichlik':[79.77,78.68,77.53,76.64,75.13,72.17,56.23,59.56]}
df=pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.48    78.68
# 2  2019        32.9  1.56    77.53
# 3  2018        32.5  1.62    76.64
# 4  2017        31.9  1.65    75.13
# 5  2016        31.4  1.66    72.17
# 6  2015        30.9  1.64    56.23
# 7  2010        28.5  1.53    59.56

# %%
df.index=[21,20,19,18,17,16,15,10]
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.48    78.68
# 19  2019        32.9  1.56    77.53
# 18  2018        32.5  1.62    76.64
# 17  2017        31.9  1.65    75.13
# 16  2016        31.4  1.66    72.17
# 15  2015        30.9  1.64    56.23
# 10  2010        28.5  1.53    59.56

# %%
#Reindex
ind=[21,20,19,18,17,16,15,10]
ind.sort()
ind
# Out:
# [10, 15, 16, 17, 18, 19, 20, 21]

# %%
df=df.reindex(ind)

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    59.56
# 15  2015        30.9  1.64    56.23
# 16  2016        31.4  1.66    72.17
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.64
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.reindex(index=range(10,22), method='ffill')
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    59.56
# 11  2010        28.5  1.53    59.56
# 12  2010        28.5  1.53    59.56
# 13  2010        28.5  1.53    59.56
# 14  2010        28.5  1.53    59.56
# 15  2015        30.9  1.64    56.23
# 16  2016        31.4  1.66    72.17
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.64
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    59.56
# 15  2015        30.9  1.64    56.23
# 16  2016        31.4  1.66    72.17
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.64
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df2=df.reindex(columns=['Aholi soni', 'Temp', 'Zichlik'])

# %%
df2.sample(3)
# Out:
#     Aholi soni  Temp  Zichlik
# 19        32.9  1.56    77.53
# 18        32.5  1.62    76.64
# 17        31.9  1.65    75.13

# %%
df.loc[[10,15, 18, 20], ['Aholi soni', 'Temp', 'Zichlik']]
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    59.56
# 15        30.9  1.64    56.23
# 18        32.5  1.62    76.64
# 20        33.5  1.48    78.68

# %%
df2=df.drop(10)
df2
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 15  2015        30.9  1.64    56.23
# 16  2016        31.4  1.66    72.17
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.64
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    59.56
# 15  2015        30.9  1.64    56.23
# 16  2016        31.4  1.66    72.17
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.64
# 19  2019        32.9  1.56    77.53
# 20  2020        33.5  1.48    78.68
# 21  2021        33.9  1.54    79.77

# %%
df.drop([15,20])
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2010        28.5  1.53    59.56
# 16  2016        31.4  1.66    72.17
# 17  2017        31.9  1.65    75.13
# 18  2018        32.5  1.62    76.64
# 19  2019        32.9  1.56    77.53
# 21  2021        33.9  1.54    79.77

# %%
df=df.drop('Yil', axis='columns')

# %%
df
# Out:
#     Aholi soni  Temp  Zichlik
# 10        28.5  1.53    59.56
# 15        30.9  1.64    56.23
# 16        31.4  1.66    72.17
# 17        31.9  1.65    75.13
# 18        32.5  1.62    76.64
# 19        32.9  1.56    77.53
# 20        33.5  1.48    78.68
# 21        33.9  1.54    79.77

# %%
df.drop('Temp', axis='columns', inplace=True)

# %%
df
# Out:
#     Aholi soni  Zichlik
# 10        28.5    59.56
# 15        30.9    56.23
# 16        31.4    72.17
# 17        31.9    75.13
# 18        32.5    76.64
# 19        32.9    77.53
# 20        33.5    78.68
# 21        33.9    79.77

# %%
df.drop([10,15,20], inplace=True)

# %%
df
# Out:
#     Aholi soni  Zichlik
# 16        31.4    72.17
# 17        31.9    75.13
# 18        32.5    76.64
# 19        32.9    77.53
# 21        33.9    79.77

# %%
data=df['Aholi soni']
data
# Out:
# 16    31.4
# 17    31.9
# 18    32.5
# 19    32.9
# 21    33.9
# Name: Aholi soni, dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %% [markdown]
# DataFrame ko'rinishida qaytarish

# %%
data=df[['Aholi soni']]
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#     Aholi soni
# 16        31.4
# 17        31.9
# 18        32.5
# 19        32.9
# 21        33.9

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data[[21]]
type(data[[21]])
# Out:
# pandas.core.series.Series

# %%
data
# Out:
# 16    31.4
# 17    31.9
# 18    32.5
# 19    32.9
# 21    33.9
# Name: Aholi soni, dtype: float64

# %%
data[0:4]
# Out:
# 16    31.4
# 17    31.9
# 18    32.5
# 19    32.9
# Name: Aholi soni, dtype: float64

# %%
data[[21,19,18]]
# Out:
# 21    33.9
# 19    32.9
# 18    32.5
# Name: Aholi soni, dtype: float64

# %%
obj=pd.Series(np.arange(8.), index=['a','b','c','d','e','f','g','h'])

# %%
obj[['a']]
# Out:
# a    0.0
# dtype: float64

# %%
obj[0:4]
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj['a':'f']
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# dtype: float64

# %%
obj['c':'h']
# Out:
# c    2.0
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# h    7.0
# dtype: float64

# %%
data[21:16]
# Out:
# Series([], Name: Aholi soni, dtype: float64)

# %%
data[16:21]
# Out:
# Series([], Name: Aholi soni, dtype: float64)

# %%
obj[['a','g']]
# Out:
# a    0.0
# g    6.0
# dtype: float64

# %%
obj['a':'c']=15

# %%
obj
# Out:
# a    15.0
# b    15.0
# c    15.0
# d     3.0
# e     4.0
# f     5.0
# g     6.0
# h     7.0
# dtype: float64

# %%
obj[obj<15]
# Out:
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# h    7.0
# dtype: float64

# %%
obj[obj==15]
# Out:
# a    15.0
# b    15.0
# c    15.0
# dtype: float64

# %%
obj[obj<7]
# Out:
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# dtype: float64
